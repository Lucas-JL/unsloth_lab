# %%
# %%capture
# import os
# !pip install --upgrade -qqq uv
# if "COLAB_" not in "".join(os.environ.keys()):
#     # If you're not in Colab, just use pip install!
#     !pip install unsloth vllm synthetic-data-kit==0.0.3
# else:
#     try: import numpy, PIL; _numpy = f'numpy=={numpy.__version__}'; _pil = f'pillow=={PIL.__version__}'
#     except: _numpy = "numpy"; _pil = "pillow"
#     try: import subprocess; is_t4 = "Tesla T4" in str(subprocess.check_output(["nvidia-smi"]))
#     except: is_t4 = False
#     _vllm, _triton = ('vllm==0.9.2', 'triton==3.2.0') if is_t4 else ('vllm==0.15.1', 'triton')
#     !uv pip install -qqq --upgrade {_vllm} {_numpy} {_pil} torchvision bitsandbytes xformers unsloth
#     !uv pip install -qqq {_triton}
#     !uv pip install synthetic-data-kit==0.0.3
# !uv pip install transformers==4.56.2
# !uv pip install --no-deps trl==0.22.2

# %%
from unsloth.dataprep import SyntheticDataKit

generator = SyntheticDataKit.from_pretrained(
    model_name="unsloth/Llama-3.2-3B-Instruct",
    max_seq_length=2048
)
# Out:
# C:\Users\libra\AppData\Local\Temp\ipykernel_18392\1034568184.py:1: UserWarning: WARNING: Unsloth should be imported before [transformers] to ensure all optimizations are applied. Your code may run slower or encounter memory issues without these optimizations.
#
# Please restructure your imports with 'import unsloth' at the top of your file.
#   from unsloth.dataprep import SyntheticDataKit
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from unsloth.dataprep import SyntheticDataKit
#       3 generator = SyntheticDataKit.from_pretrained(
#       4     model_name="unsloth/Llama-3.2-3B-Instruct",
#       5     max_seq_length=2048
#       6 )
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth\__init__.py:298
#     295     # TODO: check triton for intel installed properly.
#     296     pass
# --> 298 from .models import *
#     299 from .models import __version__
#     300 from .save import *
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth\models\__init__.py:15
#       1 # Copyright 2023-present Daniel Han-Chen & the Unsloth team. All rights reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from .llama import FastLlamaModel
#      16 from .loader import FastLanguageModel, FastVisionModel, FastTextModel, FastModel
#      17 from .mistral import FastMistralModel
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth\models\llama.py:29
#      24 from ._utils import move_to_device
#      25 from ._utils import (
#      26     _get_inference_mode_context_manager,
#      27     _prepare_model_for_qat,
#      28 )
# ---> 29 from .loader_utils import _get_fp8_mode_and_check_settings
#      30 from ..utils.packing import (
#      31     get_packed_info_from_kwargs,
#      32     mask_packed_sequence_boundaries,
#      33 )
#      34 from ..utils.attention_dispatch import (
#      35     AttentionConfig,
#      36     AttentionContext,
#      37     run_attention,
#      38     select_attention_backend,
#      39 )
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth\models\loader_utils.py:34
#      32 from unsloth.models._utils import TorchAOConfig
#      33 from unsloth_zoo.utils import Version
# ---> 34 from unsloth_zoo.vllm_utils import _get_torchao_fp8_config
#      35 import gc
#      37 transformers_version = Version(transformers_version)
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\vllm_utils.py:176
#     173     pass
#     175 # Patch apply_bnb_4bit
# --> 176 import vllm.model_executor.layers.quantization.bitsandbytes
#     177 if not hasattr(
#     178     vllm.model_executor.layers.quantization.bitsandbytes,
#     179     "apply_bnb_4bit"
#     180 ):
#     181     # Fix force using torch.bfloat16 all the time and make it dynamic
#     182     def _apply_4bit_weight(
#     183         self,
#     184         layer: torch.nn.Module,
#    (...)
#     187     ) -> torch.Tensor:
#     188         # only load the bitsandbytes module when needed
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\model_executor\__init__.py:4
#       1 # SPDX-License-Identifier: Apache-2.0
#       2 # SPDX-FileCopyrightText: Copyright contributors to the vLLM project
# ----> 4 from vllm.model_executor.parameter import BasevLLMParameter, PackedvLLMParameter
#       6 __all__ = [
#       7     "BasevLLMParameter",
#       8     "PackedvLLMParameter",
#       9 ]
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\model_executor\parameter.py:11
#       8 import torch
#       9 from torch.nn import Parameter
# ---> 11 from vllm.distributed import (
#      12     get_tensor_model_parallel_rank,
#      13     get_tensor_model_parallel_world_size,
#      14 )
#      15 from vllm.logger import init_logger
#      17 __all__ = [
#      18     "BasevLLMParameter",
#      19     "PackedvLLMParameter",
#    (...)
#      25     "RowvLLMParameter",
#      26 ]
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\distributed\__init__.py:4
#       1 # SPDX-License-Identifier: Apache-2.0
#       2 # SPDX-FileCopyrightText: Copyright contributors to the vLLM project
# ----> 4 from .communication_op import *
#       5 from .parallel_state import *
#       6 from .utils import *
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\distributed\communication_op.py:9
#       6 import torch
#       7 import torch.distributed
# ----> 9 from .parallel_state import get_tp_group
#      12 def tensor_model_parallel_all_reduce(input_: torch.Tensor) -> torch.Tensor:
#      13     """All-reduce the input tensor across model parallel group."""
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\distributed\parallel_state.py:248
#     216 def patched_fused_scaled_matmul_reduce_scatter(
#     217     A: torch.Tensor,
#     218     B: torch.Tensor,
#    (...)
#     229     use_fast_accum: bool = False,
#     230 ) -> torch.Tensor:
#     231     return torch.ops.symm_mem.fused_scaled_matmul_reduce_scatter(
#     232         A,
#     233         B,
#    (...)
#     244         use_fast_accum,
#     245     )
# --> 248 direct_register_custom_op(
#     249     op_name="all_reduce",
#     250     op_func=all_reduce,
#     251     fake_impl=all_reduce_fake,
#     252 )
#     254 direct_register_custom_op(
#     255     op_name="reduce_scatter",
#     256     op_func=reduce_scatter,
#     257     fake_impl=reduce_scatter_fake,
#     258 )
#     260 direct_register_custom_op(
#     261     op_name="all_gather",
#     262     op_func=all_gather,
#     263     fake_impl=all_gather_fake,
#     264 )
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\utils\torch_utils.py:774, in direct_register_custom_op(op_name, op_func, mutates_args, fake_impl, target_lib, dispatch_key, tags)
#     771     mutates_args = []
#     773 if dispatch_key is None:
# --> 774     from vllm.platforms import current_platform
#     776     dispatch_key = current_platform.dispatch_key
#     778 schema_str = infer_schema(op_func, mutates_args=mutates_args)
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\platforms\__init__.py:252, in __getattr__(name)
#     250 if _current_platform is None:
#     251     platform_cls_qualname = resolve_current_platform_cls_qualname()
# --> 252     _current_platform = resolve_obj_by_qualname(platform_cls_qualname)()
#     253     global _init_trace
#     254     _init_trace = "".join(traceback.format_stack())
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\utils\import_utils.py:111, in resolve_obj_by_qualname(qualname)
#     107 """
#     108 Resolve an object by its fully-qualified class name.
#     109 """
#     110 module_name, obj_name = qualname.rsplit(".", 1)
# --> 111 module = importlib.import_module(module_name)
#     112 return getattr(module, obj_name)
#
# File d:\anaconda3\envs\unsloth_lab\lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\platforms\cuda.py:16
#      13 from typing_extensions import ParamSpec
#      15 # import custom ops, trigger op registration
# ---> 16 import vllm._C  # noqa
#      17 from vllm.logger import init_logger
#      18 from vllm.utils.import_utils import import_pynvml
#
# File d:\anaconda3\envs\unsloth_lab\lib\site-packages\unsloth_zoo\temporary_patches\deepseek_v3_moe.py:271, in _setup_import_hook.<locals>.patched_import(name, globals, locals, fromlist, level)
#     269 def patched_import(name, globals=None, locals=None, fromlist=(), level=0):
#     270     # Call original import
# --> 271     module = original_import(name, globals, locals, fromlist, level)
#     273     # Check if this is DeepSeekV3 being imported
#     274     if (
#     275         name == "transformers.models.deepseek_v3"
#     276         or name == "transformers.models.deepseek_v3.modeling_deepseek_v3"
#     277         or (fromlist and any("deepseek_v3" in str(f) for f in fromlist))
#     278     ):
#     279         # Try to apply patches
#
# ModuleNotFoundError: No module named 'vllm._C'

# %%
import vllm
print(vllm.__version__)
# 尝试导入核心模块看是否报错
from vllm import _C 
print("Success: vllm._C loaded correctly.")
# Out:
# 0.16.0
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       2 print(vllm.__version__)
#       3 # 尝试导入核心模块看是否报错
# ----> 4 from vllm import _C
#       5 print("Success: vllm._C loaded correctly.")
#
# ImportError: cannot import name '_C' from 'vllm' (d:\anaconda3\envs\unsloth_lab\lib\site-packages\vllm\__init__.py)
